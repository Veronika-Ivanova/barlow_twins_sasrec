# %%
BT:
BS = 256, DP = 0.3, CE!

64 0.2 0.5   hr@5:0.0600 ndcg@5:0.0406 ndcg@10:0.0506

64 1.1 0.1   hr@1:0.0147 ndcg@5:0.0314 ndcg@10:0.0423

64 0.3 0.5   hr@5:0.0627 ndcg@5:0.0444 ndcg@10:0.0565

BT + SCE!

64 0.3 0.5   hr@5:0.06 ndcg@5:0.0391 ndcg@10:0.0522


CE:
BS = 256, DP = 0.3
hr@5:0.052 ndcg@5:0.0353 ndcg@10:0.0453


SCE:
BS = 256, DP = 0.3
hr@5:0.0573 ndcg@5:0.0407 ndcg@10:0.0476



DROSS + BT:
BS = 256, DP = 0.3 NS = 256
hr@5:0.056 ndcg@5:0.0366 ndcg@10:0.0482

# %%
SLIDING WINDOW AUG
BT + CE:
128 1.5 0.2 hr@5:0.056 ndcg@5:0.0388 ndcg@10:0.0478
# Out:
# 1.0942408376963353

# %%
api {
# Ivan Razvorotnev's workspace
web_server:https://app.clear.ml/
api_server:https://api.clear.ml
files_server:https://files.clear.ml
credentials {
"access_key"="ABP1QYAF3E5FG24SDKULXIR2ESEUNL"
"secret_key"="EeLEn8EveqxBKL7oBo1-TnIh2gMXw70D-3_EbH57gdVbMrywzLEcBSx_vAzHe-ul45o"
}
}

# %%
from clearml import Task
import os
from collections import defaultdict

# %%
# %env CLEARML_WEB_HOST=https://app.clear.ml/
# %env CLEARML_API_HOST=https://api.clear.ml
# %env CLEARML_FILES_HOST=https://files.clear.ml
# %env CLEARML_API_ACCESS_KEY=ABP1QYAF3E5FG24SDKULXIR2ESEUNL
# %env CLEARML_API_SECRET_KEY=EeLEn8EveqxBKL7oBo1-TnIh2gMXw70D-3_EbH57gdVbMrywzLEcBSx_vAzHe-ul45o
# Out:
# env: CLEARML_WEB_HOST=https://app.clear.ml/
# env: CLEARML_API_HOST=https://api.clear.ml
# env: CLEARML_FILES_HOST=https://files.clear.ml
# env: CLEARML_API_ACCESS_KEY=ABP1QYAF3E5FG24SDKULXIR2ESEUNL
# env: CLEARML_API_SECRET_KEY=EeLEn8EveqxBKL7oBo1-TnIh2gMXw70D-3_EbH57gdVbMrywzLEcBSx_vAzHe-ul45o

# %%
project_tasks = Task.get_tasks(project_name="BTSasRec")

# %%
filter_name = 'YELP'
task_artefats = defaultdict(list)
for t in project_tasks:
    print(t.name)
    name = t.name
    artefacts = {}
    artefacts["metrics"] = t.get_reported_scalars()
    artefacts["parameters"] = t.get_parameters()
    task_artefats[name].append(artefacts)
# Out:
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# CE Barlow twins
# Full CE
# Scalable CE
# Scalable CE
# YELP. Scalable CE
# YELP. Full CE
# YELP. Full CE
# CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins
# YELP. CE Barlow twins

# %%
task_artefats["YELP. CE Barlow twins"][2]["parameters"]
# Out:
# {'Hydra/_allow_omegaconf_edit_': 'False',
#  'Args/help': 'False',
#  'Args/hydra_help': 'False',
#  'Args/cfg': '',
#  'Args/resolve': 'False',
#  'Args/package': '',
#  'Args/run': 'False',
#  'Args/multirun': 'False',
#  'Args/shell_completion': 'False',
#  'Args/config_path': './configs/temporal/yelp',
#  'Args/config_name': 'ce_bt',
#  'Args/config_dir': '',
#  'Args/experimental_rerun': '',
#  'Args/info': '',
#  'General/cuda_visible_devices': '0',
#  'General/data_path': 'data/yelp.csv',
#  'General/splitting': 'temporal',
#  'General/project_name': 'BTSasRec',
#  'General/task_name': 'YELP. CE Barlow twins',
#  'General/dataloader/batch_size': '64',
#  'General/dataloader/n_neg_samples': '0',
#  'General/dataloader/augmentations/target_semantic/enable': 'True',
#  'General/model': 'SASRec',
#  'General/model_params/fwd_type': 'ce',
#  'General/model_params/sampling': 'no_sampling',
#  'General/model_params/ssl/lmd': '1.0',
# ...

# %%
for metric_title, series in t.get_reported_scalars().items():
    print(f"Metric Group: {metric_title}")
    for series_name, values in series.items():
        print(f"  Series: {series_name}")
        for entry in values:
            print(entry)
# Out:
# Metric Group: :monitor:gpu
#   Series: gpu_0_mem_free_gb
# name
# x
# y
#   Series: gpu_0_mem_usage
# name
# x
# y
#   Series: gpu_0_mem_used_gb
# name
# x
# y
#   Series: gpu_0_temperature
# name
# x
# y
#   Series: gpu_0_utilization
# name
# x
# y
# Metric Group: :monitor:machine
#   Series: cpu_usage
# name
# x
# y
#   Series: disk_free_percent
# name
# x
# y
#   Series: io_read_mbs
# name
# x
# y
#   Series: io_write_mbs
# name
# x
# y
#   Series: memory_free_gb
# name
# x
# y
#   Series: memory_used_gb
# name
# x
# y
#   Series: network_rx_mbs
# name
# x
# y
#   Series: network_tx_mbs
# name
# x
# y
# Metric Group: Loss
#   Series: Val
# name
# x
# y
# Metric Group: NDCG
#   Series: Val
# name
# x
# y

# %%
t.get_reported_scalars()["Loss"]
# Out:
# {'name': 'Val',
#  'x': [0, 5, 10, 15, 20, 25, 30, 35],
#  'y': [5.775699615478516,
#   2.968118667602539,
#   2.357985734939575,
#   2.0444936752319336,
#   1.849267840385437,
#   1.6974472999572754,
#   1.5705852508544922,
#   1.4630070924758911]}
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
